# %%
import pandas as pd
df=pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#HISTOGRAMA DE PANDAS

df["math score"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#HISTOGRAMA DE Seaborn

import seaborn as sns
sns.distplot(df["math score"])
# Out:
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\2220794590.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["math score"])
# <Axes: xlabel='math score', ylabel='Density'>

# %%
#HISTOGRAMA ALTERNATIVO DE Seaborn

sns.displot(df["math score"]) # SIN T EN DISTPLOT

# %%
#HISTOGRAMA ALTERNATIVO DE Seaborn con curva de gartner

sns.displot(df["math score"],kde= True, bins= 10)

# %%
#QUITAR HISTOGRAMA PARA DEJAR SÓLO CURVA
sns.distplot(df["math score"] ,hist=False)
# Out:
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\822098241.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["math score"] ,hist=False)
# <Axes: xlabel='math score', ylabel='Density'>

# %%
#QUITAR HISTOGRAMA PARA DEJAR SÓLO CURVA Y COLOREARLA
sns.distplot(df["math score"] ,hist=False, kde_kws={"shade":True})
# Out:
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\286957357.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["math score"] ,hist=False, kde_kws={"shade":True})
# C:\Users\odela\Documents\Anaconda 4\Lib\site-packages\seaborn\distributions.py:2496: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <Axes: xlabel='math score', ylabel='Density'>

# %%
# CREACIÓN DE DIAGRAMAS DE DISPERSIÓN CON RECTA DE REGRESIÓN
sns.regplot(x="reading score", y="writing score", data=df)
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
# CREACIÓN DE DIAGRAMAS DE DISPERSIÓN CON RECTA DE REGRESIÓN OTRA OPCIÓN AÚN MÁS VISUAL
sns.lmplot(x="reading score", y="writing score", data=df)

# %%
# Gráfico de dispersión con regresión lineal por categoria de género
sns.lmplot(x="reading score", y="writing score", data=df, hue="gender")

# %%
# Gráfico de dispersión con regresión lineal por categoria de género dividiendo gráficos
sns.lmplot(x="reading score", y="writing score", data=df, col="gender")

# %%
# Gráfico de dispersión con regresión lineal por categoria de raza dividiendo gráficos
sns.lmplot(x="reading score", y="writing score", data=df, col="race/ethnicity")

# %%
# Estilos de Histograma

for style in[ "dark", "whitegrid","darkgrid","ticks"]:
    sns.set_style(style)
    sns.displot(df["reading score"])

# %%
# REMOCIÓN DE EJES

sns.set_style("ticks")
sns.displot(df["reading score"], kde=True)
sns.despine(left= True, bottom= True)

# %%
# COMBINACIÓN DE PARÁMETROS CON MATPLOTLIB

import matplotlib.pyplot as plt

fig, ax= plt.subplots()
sns.distplot(df["writing score"], ax= ax)
ax.set_xlabel("Score de escritura")
ax.set_ylabel("Frecuencia relativa")
# Out:
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\2543728013.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["writing score"], ax= ax)
# Text(0, 0.5, 'Frecuencia relativa')

# %%
# TRUNCAMIENTO DE ESCALAS DE VISUALIZACIÓN
fig, ax= plt.subplots()
sns.distplot(df["writing score"], ax= ax)
ax.set(xlabel="Score de escritura",ylabel= "Frecuencia relativa",xlim= (0,90),title="HISTOGRAMA DE FRECUENCIAS PARA PUNTAJE DE ESRITURA")
# Out:
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\2119103972.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["writing score"], ax= ax)
# [Text(0.5, 0, 'Score de escritura'),
#  Text(0, 0.5, 'Frecuencia relativa'),
#  (0.0, 90.0),
#  Text(0.5, 1.0, 'HISTOGRAMA DE FRECUENCIAS PARA PUNTAJE DE ESRITURA')]

# %%
fig, (ax0, ax1)= plt.subplots(nrows=1, ncols=2 ,sharey=True)
sns.distplot(df["writing score"],ax=ax0) #Histograma para todas las observaciones
sns.distplot(df.query('gender == "male"')["writing score"],ax=ax1) #Histograma para los hombres
ax0.set(xlabel= "Puntaje general de escritura")
ax1.set(xlabel= "Puntaje de escritura para hombres")
ax1.axvline(x=75, label= "objetivo", linestyle="--")
ax1.legend()
# Out:
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\3173742259.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["writing score"],ax=ax0) #Histograma para todas las observaciones
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\3173742259.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
# ASIGNACIÓNEs DE COLORES PARA EL HISTOGRAMA

paleta=["deep","muted","pastel","bright", "dark","colorblind"] # opciones de colores

for p in paleta:
    sns.set_palette(p)
    sns.displot(df["reading score"], kde=True)

# %%
# CREACIÓN DE UN STRIPPLOT ( GRÁFICO DE BANDAS Y FRANJAS)

sns.stripplot(data= df3 , y="writing score", x= "math score",jitter=True, palette="husl")
# Out:
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\617414405.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data= df3 , y="writing score", x= "math score",jitter=True, palette="husl")
# <Axes: xlabel='math score', ylabel='writing score'>

# %%
fig, ax= plt.subplots()
sns.stripplot(data= df2 , y="writing score", x= "math score",jitter=True, palette="husl" )
ax.axes.xaxis.set_ticks([])
# Out:
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\2607284194.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data= df2 , y="writing score", x= "math score",jitter=True, palette="husl" )
# []

# %%
fig, ax= plt.subplots()
sns.stripplot(data= df , y="writing score", x= "race/ethnicity",jitter=True, palette="husl")
plt.show
# Out:
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\1776289123.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data= df , y="writing score", x= "race/ethnicity",jitter=True, palette="husl")
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# CREACIÓN DE UN SWARMPLOT (DIAGRAMA DE ENJANBRE)
# BUSCA COLOCAR OBSERVACIONES DE MANERA QUE NO SE EMPALMEN

sns.swarmplot(data= df , y="writing score", x= "race/ethnicity", palette="husl")
plt.show
# Out:
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\202633399.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data= df , y="writing score", x= "race/ethnicity", palette="husl")
# C:\Users\odela\Documents\Anaconda 4\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 11.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\odela\Documents\Anaconda 4\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>
# ...

# %%
# CREACIÓN DE BOXPLOT ( DIAGRAMA DE CAJA)

sns.boxplot(data= df , y="writing score", x= "race/ethnicity",palette="husl")
# Out:
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\3717448267.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data= df , y="writing score", x= "race/ethnicity",palette="husl")
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
print(sns.__version__)
# Out:
# 0.13.2

# %%
# GRÁFICO DE VIOLÍN (MEZCLA UN BOXPLOT CON FUNCIÓN DE DENSIDAD KERNEL
# EN LAS PARTES MÁS ANCHAS, MUESTRA DONDE HAY MAYOR CONCENTRACIÓN

sns.violinplot(data= df , y="writing score", x= "race/ethnicity",palette="husl")
# Out:
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\423073741.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data= df , y="writing score", x= "race/ethnicity",palette="husl")
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
# CREACIÓN DE IVPLOT (LETTER. VALUE- PLOT)
# MEZCLA DE BOXPLOT Y VIOLÍNPLOT( CONVENIENTE PARA BASES DE DATOS GRANDES
sns.catplot(x= "race/ethnicity" , y="writing score", kind= "boxen" ,palette="husl", data= df)
# Out:
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\3342663113.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x= "race/ethnicity" , y="writing score", kind= "boxen" ,palette="husl", data= df)

# %%
# CREACIÓN DE BARPLOT

sns.barplot(x= "race/ethnicity" , y="writing score",palette="husl", data= df)
# Out:
# C:\Users\odela\AppData\Local\Temp\ipykernel_12272\3500634526.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= "race/ethnicity" , y="writing score",palette="husl", data= df)
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
# CREACIÓN DE BARPLOT

sns.barplot(x= "race/ethnicity" , y="writing score",palette="husl", data= df, hue="lunch")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
# CREACIÓN DE POINTPLOT CON COMPARACIÓN DEL TIPO DE LUNCH

sns.pointplot(x= "race/ethnicity" , y="writing score",palette="husl", data= df, hue="lunch")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
# CREACIÓN DE COUNTPLOT

sns.countplot(y= "race/ethnicity" ,  data= df, hue="lunch")
# Out:
# <Axes: xlabel='count', ylabel='race/ethnicity'>

# %%
# GRAFICOS DE REGRESIÓN CON REGPLOT

sns.regplot(x= "reading score" ,y= "writing score" , data= df, marker="+")
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
# GRAFICOS DE RESIDUALES

sns.residplot(x= "reading score" ,y= "writing score" , data= df)
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
# GRAFICOS DE REGRESIÓN CON REGPLOT Y MEDIA POR VALOR DE X (UTIL PARA ENFATIZAR TENDENCIAS)
import numpy as np
sns.regplot(x= "reading score" ,y= "writing score" , data= df, x_estimator=np.mean)
# Out:
# <Axes: xlabel='reading score', ylabel='writing score'>

# %%
# MAPA DE CALOR PARA UNA MATRIZ DE CORRELACIÓN 

sns.heatmap(df[['math score', 'reading score', 'writing score']].corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df[['math score', 'reading score', 'writing score']].corr(), annot=True)
# Out:
# <Axes: >

# %%
# CREACIÓN DE TABLA CRUZADA

pd.crosstab(df["gender"],df["race/ethnicity"],values= df["math score"], aggfunc= "mean")
# Out:
# race/ethnicity    group A    group B    group C    group D    group E
# gender
# female          58.527778  61.403846  62.033333  65.248062  70.811594
# male            63.735849  65.930233  67.611511  69.413534  76.746479

# %%
# MAPA DE CALOR PARA TABLA CRUZADA

sns.heatmap(pd.crosstab(df["gender"],df["race/ethnicity"],values= df["math score"], aggfunc= "mean"),annot= True)
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='gender'>

# %%
print(df["race/ethnicity"].unique())
print(df.columns)
# Out:
# ['group B' 'group C' 'group A' 'group D' 'group E']
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# USO DE FACETGRID

import seaborn as sns

order = ["group A", "group B", "group C", "group D", "group E"]  # Ajusta según tu df
graf = sns.FacetGrid(df, col="race/ethnicity", col_order=order)
graf.map(sns.boxplot, "math score")
# Out:
# C:\Users\odela\Documents\Anaconda 4\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# USO DE FACTORPLOT

sns.catplot(x="math score", data= df, col="race/ethnicity", kind= "box")

# %%
#  FACETGRID PARA GRÁFICO DE DISPERSIÓN

graf = sns.FacetGrid(df, col="race/ethnicity")
graf.map(plt.scatter, "reading score", "writing score")

# %%
#  GRÁFICOS TABULARES DE REGRESIÓN

sns.lmplot(data= df, x= "reading score", y= "writing score", col= "gender", row="race/ethnicity")

# %%
#  CREACIÓN DE UNA GRÁFICA CONJUNTA, DEJA VER LOS SESGOS PARA WRITING Y READING

graf=sns.JointGrid(data=df, x="reading score", y="writing score")
graf.plot(sns.regplot, sns.distplot)
# Out:
# C:\Users\odela\Documents\Anaconda 4\Lib\site-packages\seaborn\axisgrid.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(self.x, **orient_kw_x, **kwargs)
# C:\Users\odela\Documents\Anaconda 4\Lib\site-packages\seaborn\axisgrid.py:1892: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#  DEGRADADO GRÁFICA DE DISPERSIÓN 

graf=sns.jointplot(data=df, x="reading score", y="writing score", kind= "hex")

# %%
#  ELEGIR PUNTOS A GRAFICAR ( QUERY) sólo género másculino

graf=sns.jointplot(data=df.query('gender== "male"'), x="reading score", y="writing score", kind= "scatter")

# %%
fig.savefig("reading.png")
